# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/corazzon/finance-data-analysis/blob/main/4.1%20ETF%20%EB%AA%A9%EB%A1%9D%20%EC%88%98%EC%A7%91-output.ipynb)
#
#
# ## ETF란?
# * ETF(상장지수펀드)는 기초지수의 성과를 추적하는 것이 목표인 인덱스펀드로, 거래소에 상장되어 있어서 개별주식과 마찬가지로 기존의 주식계좌를 통해 거래를 할 수 있습니다. 그 구성종목과 수량 등 자산구성내역(PDF)이 투명하게 공개되어 있고, 장중에는 실시간으로 순자산가치(NAV)가 제공되어 거래에 참고하실 수 있습니다. ETF는 1좌를 거래할 수 있는 최소한의 금액만으로 분산투자 효과를 누릴 수 있어 효율적인 투자수단이며, 펀드보다 운용보수가 낮고 주식에 적용되는 거래세도 붙지 않습니다.
#     * 출처 : [ETF : 네이버 금융](https://finance.naver.com/sise/etf.nhn)
#
#
# ## 크롬 브라우저의 네트워크 정보를 통한 데이터 수집
# * json 데이터 수집과 파일저장 방법
#
# * [ETF : 네이버 금융](https://finance.naver.com/sise/etf.nhn)

# %%
# 라이브러리를 불러옵니다.
# 데이터 분석을 위한 pandas, 수치계산을 위한 numpy, http 요청을 위한 requests를 받아옵니다.
import pandas as pd
import numpy as np
import requests

# %%
# 수집할 url을 가져옵니다.
url = "https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc"

# %% [markdown]
# ## Pandas를 통한 요청

# %%
# pd.read_html(url)

# %% [markdown]
# ## JSON
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c9/JSON_vector_logo.svg/300px-JSON_vector_logo.svg.png" width="100">
#
# JSON(제이슨, JavaScript Object Notation)은 속성-값 쌍( attribute–value pairs and array data types (or any other serializable value)) 또는 "키-값 쌍"으로 이루어진 데이터 오브젝트를 전달하기 위해 인간이 읽을 수 있는 텍스트를 사용하는 개방형 표준 포맷이다. 비동기 브라우저/서버 통신 (AJAX)을 위해, 넓게는 XML(AJAX가 사용)을 대체하는 주요 데이터 포맷이다. 특히, 인터넷에서 자료를 주고 받을 때 그 자료를 표현하는 방법으로 알려져 있다. 자료의 종류에 큰 제한은 없으며, 특히 컴퓨터 프로그램의 변수값을 표현하는 데 적합하다.
# 본래는 자바스크립트 언어로부터 파생되어 자바스크립트의 구문 형식을 따르지만 언어 독립형 데이터 포맷이다. 즉, 프로그래밍 언어나 플랫폼에 독립적이므로, 구문 분석 및 JSON 데이터 생성을 위한 코드는 C, C++, C#, 자바, 자바스크립트, 펄, 파이썬 등 수많은 프로그래밍 언어에서 쉽게 이용할 수 있다.
#
# * 출처 : [JSON - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/JSON)

# %% [markdown]
# ## requests를 통한 HTTP 요청
# * [Requests: HTTP for Humans™ — Requests documentation](https://requests.readthedocs.io/en/master/)

# %%
# requests 라이브러리를 통해 url을 받아옵니다.
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'resultCode': 'success',
#  'result': {'etfItemList': [{'itemcode': '459580',
#     'etfTabCode': 6,
#     'itemname': 'KODEX CD금리액티브(합성)',
#     'nowVal': 1038075,
#     'risefall': '2',
#     'changeVal': 215,
#     'changeRate': 0.02,
#     'nav': 1038075.0,
#     'threeMonthEarnRate': 0.9079,
#     'quant': 331808,
#     'amonut': 344440,
#     'marketSum': 90560},
#    {'itemcode': '357870',
#     'etfTabCode': 6,
#     'itemname': 'TIGER CD금리투자KIS(합성)',
#     'nowVal': 54425,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.04,
#     'nav': 54421.0,
#     'threeMonthEarnRate': 0.9272,
#     'quant': 161096,
#     'amonut': 8767,
#     'marketSum': 72972},
#    {'itemcode': '069500',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 200',
#     'nowVal': 36755,
#     'risefall': '2',
#     'changeVal': 365,
#     'changeRate': 1.0,
#     'nav': 36797.0,
#     'threeMonthEarnRate': 3.1661,
#     'quant': 2884876,
#     'amonut': 105860,
#     'marketSum': 62833},
#    {'itemcode': '423160',
#     'etfTabCode': 6,
#     'itemname': 'KODEX KOFR금리액티브(합성)',
#     'nowVal': 106990,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.02,
#     'nav': 106977.0,
#     'threeMonthEarnRate': 0.9006,
#     'quant': 23294,
#     'amonut': 2492,
#     'marketSum': 52161},
#    {'itemcode': '449170',
#     'etfTabCode': 6,
#     'itemname': 'TIGER KOFR금리액티브(합성)',
#     'nowVal': 105540,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.03,
#     'nav': 105519.0,
#     'threeMonthEarnRate': 0.9179,
#     'quant': 55531,
#     'amonut': 5860,
#     'marketSum': 36978},
#    {'itemcode': '360750',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500',
#     'nowVal': 18135,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.11,
#     'nav': 18118.0,
#     'threeMonthEarnRate': 6.6074,
#     'quant': 1214859,
#     'amonut': 22030,
#     'marketSum': 35499},
#    {'itemcode': '133690',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국나스닥100',
#     'nowVal': 114380,
#     'risefall': '2',
#     'changeVal': 420,
#     'changeRate': 0.37,
#     'nav': 114179.0,
#     'threeMonthEarnRate': 5.9564,
#     'quant': 121675,
#     'amonut': 13912,
#     'marketSum': 33330},
#    {'itemcode': '273130',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 종합채권(AA-이상)액티브',
#     'nowVal': 110820,
#     'risefall': '2',
#     'changeVal': 215,
#     'changeRate': 0.19,
#     'nav': 110815.0,
#     'threeMonthEarnRate': 1.3165,
#     'quant': 7174,
#     'amonut': 794,
#     'marketSum': 27525},
#    {'itemcode': '465680',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 24-12 은행채(AA+이상)액티브',
#     'nowVal': 10315,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.05,
#     'nav': 10311.0,
#     'threeMonthEarnRate': 1.0284,
#     'quant': 9694,
#     'amonut': 99,
#     'marketSum': 24933},
#    {'itemcode': '381180',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국필라델피아반도체나스닥',
#     'nowVal': 18720,
#     'risefall': '5',
#     'changeVal': -70,
#     'changeRate': -0.37,
#     'nav': 18609.0,
#     'threeMonthEarnRate': 7.3148,
#     'quant': 2094262,
#     'amonut': 39093,
#     'marketSum': 24682},
#    {'itemcode': '381170',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국테크TOP10 INDXX',
#     'nowVal': 19525,
#     'risefall': '2',
#     'changeVal': 120,
#     'changeRate': 0.62,
#     'nav': 19438.0,
#     'threeMonthEarnRate': 14.1812,
#     'quant': 1382522,
#     'amonut': 26945,
#     'marketSum': 23049},
#    {'itemcode': '102110',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 200',
#     'nowVal': 36810,
#     'risefall': '2',
#     'changeVal': 335,
#     'changeRate': 0.92,
#     'nav': 36858.0,
#     'threeMonthEarnRate': 3.2191,
#     'quant': 772243,
#     'amonut': 28417,
#     'marketSum': 22325},
#    {'itemcode': '278530',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 200TR',
#     'nowVal': 12790,
#     'risefall': '2',
#     'changeVal': 130,
#     'changeRate': 1.03,
#     'nav': 12797.0,
#     'threeMonthEarnRate': 3.2284,
#     'quant': 135573,
#     'amonut': 1725,
#     'marketSum': 21717},
#    {'itemcode': '122630',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 레버리지',
#     'nowVal': 19070,
#     'risefall': '2',
#     'changeVal': 380,
#     'changeRate': 2.03,
#     'nav': 19252.0,
#     'threeMonthEarnRate': 3.9803,
#     'quant': 15426991,
#     'amonut': 293202,
#     'marketSum': 21435},
#    {'itemcode': '371460',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나전기차SOLACTIVE',
#     'nowVal': 7975,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.63,
#     'nav': 7939.0,
#     'threeMonthEarnRate': 7.6248,
#     'quant': 945813,
#     'amonut': 7557,
#     'marketSum': 20103},
#    {'itemcode': '455890',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 머니마켓액티브',
#     'nowVal': 52355,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.03,
#     'nav': 52352.0,
#     'threeMonthEarnRate': 1.0421,
#     'quant': 214994,
#     'amonut': 11255,
#     'marketSum': 17560},
#    {'itemcode': '233740',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 코스닥150레버리지',
#     'nowVal': 10805,
#     'risefall': '2',
#     'changeVal': 290,
#     'changeRate': 2.76,
#     'nav': 10885.0,
#     'threeMonthEarnRate': -6.8133,
#     'quant': 20574582,
#     'amonut': 220824,
#     'marketSum': 13701},
#    {'itemcode': '315930',
#     'etfTabCode': 2,
#     'itemname': 'KODEX Top5PlusTR',
#     'nowVal': 23380,
#     'risefall': '2',
#     'changeVal': 210,
#     'changeRate': 0.91,
#     'nav': 23379.0,
#     'threeMonthEarnRate': 5.72,
#     'quant': 7214,
#     'amonut': 168,
#     'marketSum': 13233},
#    {'itemcode': '470260',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 24-12 금융채(AA-이상)',
#     'nowVal': 51350,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.05,
#     'nav': 51345.0,
#     'threeMonthEarnRate': 1.1125,
#     'quant': 1293,
#     'amonut': 66,
#     'marketSum': 13226},
#    {'itemcode': '252670',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 200선물인버스2X',
#     'nowVal': 2075,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -1.89,
#     'nav': 2079.0,
#     'threeMonthEarnRate': -6.1086,
#     'quant': 152607741,
#     'amonut': 317660,
#     'marketSum': 13143},
#    {'itemcode': '214980',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기채권PLUS',
#     'nowVal': 110770,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.04,
#     'nav': 110768.0,
#     'threeMonthEarnRate': 0.9385,
#     'quant': 6796,
#     'amonut': 752,
#     'marketSum': 12878},
#    {'itemcode': '379800',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국S&P500TR',
#     'nowVal': 16530,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.18,
#     'nav': 16507.0,
#     'threeMonthEarnRate': 6.7484,
#     'quant': 1024887,
#     'amonut': 16931,
#     'marketSum': 12877},
#    {'itemcode': '453850',
#     'etfTabCode': 6,
#     'itemname': 'ACE 미국30년국채액티브(H)',
#     'nowVal': 8410,
#     'risefall': '2',
#     'changeVal': 85,
#     'changeRate': 1.02,
#     'nav': 8440.0,
#     'threeMonthEarnRate': -2.0042,
#     'quant': 1446855,
#     'amonut': 12192,
#     'marketSum': 12657},
#    {'itemcode': '305540',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 2차전지테마',
#     'nowVal': 22750,
#     'risefall': '2',
#     'changeVal': 765,
#     'changeRate': 3.48,
#     'nav': 22740.0,
#     'threeMonthEarnRate': -9.4384,
#     'quant': 621865,
#     'amonut': 14098,
#     'marketSum': 12433},
#    {'itemcode': '305720',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 2차전지산업',
#     'nowVal': 19240,
#     'risefall': '2',
#     'changeVal': 690,
#     'changeRate': 3.72,
#     'nav': 19256.0,
#     'threeMonthEarnRate': -9.4546,
#     'quant': 2828982,
#     'amonut': 54300,
#     'marketSum': 12391},
#    {'itemcode': '102780',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 삼성그룹',
#     'nowVal': 9190,
#     'risefall': '2',
#     'changeVal': 105,
#     'changeRate': 1.16,
#     'nav': 9186.0,
#     'threeMonthEarnRate': 0.514,
#     'quant': 84024,
#     'amonut': 771,
#     'marketSum': 12296},
#    {'itemcode': '148020',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 200',
#     'nowVal': 37000,
#     'risefall': '2',
#     'changeVal': 385,
#     'changeRate': 1.05,
#     'nav': 37029.0,
#     'threeMonthEarnRate': 3.2135,
#     'quant': 185883,
#     'amonut': 6872,
#     'marketSum': 12173},
#    {'itemcode': '292150',
#     'etfTabCode': 2,
#     'itemname': 'TIGER TOP10',
#     'nowVal': 12425,
#     'risefall': '2',
#     'changeVal': 190,
#     'changeRate': 1.55,
#     'nav': 12425.0,
#     'threeMonthEarnRate': 4.3153,
#     'quant': 163277,
#     'amonut': 2023,
#     'marketSum': 11804},
#    {'itemcode': '310970',
#     'etfTabCode': 1,
#     'itemname': 'TIGER MSCI Korea TR',
#     'nowVal': 15630,
#     'risefall': '2',
#     'changeVal': 245,
#     'changeRate': 1.59,
#     'nav': 15623.0,
#     'threeMonthEarnRate': 2.0234,
#     'quant': 2153,
#     'amonut': 33,
#     'marketSum': 11519},
#    {'itemcode': '385540',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 종합채권(A-이상)액티브',
#     'nowVal': 102660,
#     'risefall': '2',
#     'changeVal': 190,
#     'changeRate': 0.19,
#     'nav': 102617.0,
#     'threeMonthEarnRate': 1.2426,
#     'quant': 11268,
#     'amonut': 1156,
#     'marketSum': 11122},
#    {'itemcode': '360200',
#     'etfTabCode': 4,
#     'itemname': 'ACE 미국S&P500',
#     'nowVal': 18335,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.11,
#     'nav': 18321.0,
#     'threeMonthEarnRate': 6.6546,
#     'quant': 227319,
#     'amonut': 4168,
#     'marketSum': 10359},
#    {'itemcode': '458730',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국배당다우존스',
#     'nowVal': 11410,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.04,
#     'nav': 11398.0,
#     'threeMonthEarnRate': 3.5672,
#     'quant': 736452,
#     'amonut': 8403,
#     'marketSum': 9670},
#    {'itemcode': '379810',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국나스닥100TR',
#     'nowVal': 17090,
#     'risefall': '2',
#     'changeVal': 70,
#     'changeRate': 0.41,
#     'nav': 17058.0,
#     'threeMonthEarnRate': 6.0831,
#     'quant': 440265,
#     'amonut': 7520,
#     'marketSum': 9348},
#    {'itemcode': '229200',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스닥150',
#     'nowVal': 13735,
#     'risefall': '2',
#     'changeVal': 200,
#     'changeRate': 1.48,
#     'nav': 13781.0,
#     'threeMonthEarnRate': -2.7955,
#     'quant': 9187719,
#     'amonut': 126015,
#     'marketSum': 8797},
#    {'itemcode': '367380',
#     'etfTabCode': 4,
#     'itemname': 'ACE 미국나스닥100',
#     'nowVal': 19655,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 0.38,
#     'nav': 19619.0,
#     'threeMonthEarnRate': 6.014,
#     'quant': 135990,
#     'amonut': 2672,
#     'marketSum': 8294},
#    {'itemcode': '447820',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 24-10 회사채(A+이상)액티브',
#     'nowVal': 55020,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.01,
#     'nav': 55031.0,
#     'threeMonthEarnRate': 1.019,
#     'quant': 38009,
#     'amonut': 2091,
#     'marketSum': 8063},
#    {'itemcode': '396500',
#     'etfTabCode': 2,
#     'itemname': 'TIGER Fn반도체TOP10',
#     'nowVal': 13195,
#     'risefall': '2',
#     'changeVal': 205,
#     'changeRate': 1.58,
#     'nav': 13189.0,
#     'threeMonthEarnRate': 14.0548,
#     'quant': 1870000,
#     'amonut': 24615,
#     'marketSum': 8049},
#    {'itemcode': '436140',
#     'etfTabCode': 6,
#     'itemname': 'SOL 종합채권(AA-이상)액티브',
#     'nowVal': 107245,
#     'risefall': '2',
#     'changeVal': 200,
#     'changeRate': 0.19,
#     'nav': 107260.0,
#     'threeMonthEarnRate': 1.27,
#     'quant': 5332,
#     'amonut': 571,
#     'marketSum': 7943},
#    {'itemcode': '458760',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국배당+7%프리미엄다우존스',
#     'nowVal': 10175,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 10159.0,
#     'threeMonthEarnRate': 3.0692,
#     'quant': 979942,
#     'amonut': 9961,
#     'marketSum': 7626},
#    {'itemcode': '453540',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 25-10 회사채(A+이상)액티브',
#     'nowVal': 52885,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.05,
#     'nav': 52865.0,
#     'threeMonthEarnRate': 1.1862,
#     'quant': 87209,
#     'amonut': 4611,
#     'marketSum': 7585},
#    {'itemcode': '139260',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 IT',
#     'nowVal': 34365,
#     'risefall': '2',
#     'changeVal': 410,
#     'changeRate': 1.21,
#     'nav': 34373.0,
#     'threeMonthEarnRate': 6.8962,
#     'quant': 65216,
#     'amonut': 2239,
#     'marketSum': 7519},
#    {'itemcode': '272580',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 단기채권액티브',
#     'nowVal': 53975,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.04,
#     'nav': 53965.0,
#     'threeMonthEarnRate': 0.9727,
#     'quant': 5042,
#     'amonut': 272,
#     'marketSum': 7503},
#    {'itemcode': '476810',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 25-11 은행채(AA-이상)PLUS액티브',
#     'nowVal': 10130,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.1,
#     'nav': 10130.0,
#     'threeMonthEarnRate': 1.1988,
#     'quant': 14879,
#     'amonut': 150,
#     'marketSum': 7475},
#    {'itemcode': '157450',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 단기통안채',
#     'nowVal': 107145,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.03,
#     'nav': 107159.0,
#     'threeMonthEarnRate': 0.8423,
#     'quant': 19026,
#     'amonut': 2038,
#     'marketSum': 7413},
#    {'itemcode': '153130',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기채권',
#     'nowVal': 109845,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.03,
#     'nav': 109841.0,
#     'threeMonthEarnRate': 0.8862,
#     'quant': 12339,
#     'amonut': 1355,
#     'marketSum': 7362},
#    {'itemcode': '294400',
#     'etfTabCode': 1,
#     'itemname': 'KOSEF 200TR',
#     'nowVal': 46510,
#     'risefall': '2',
#     'changeVal': 465,
#     'changeRate': 1.01,
#     'nav': 46542.0,
#     'threeMonthEarnRate': 3.1606,
#     'quant': 83285,
#     'amonut': 3871,
#     'marketSum': 6977},
#    {'itemcode': '475630',
#     'etfTabCode': 7,
#     'itemname': 'TIGER 1년은행양도성예금증서액티브(합성)',
#     'nowVal': 1012950,
#     'risefall': '2',
#     'changeVal': 305,
#     'changeRate': 0.03,
#     'nav': 1012946.0,
#     'threeMonthEarnRate': 0.9497,
#     'quant': 37891,
#     'amonut': 38381,
#     'marketSum': 6919},
#    {'itemcode': '356540',
#     'etfTabCode': 6,
#     'itemname': 'ACE 종합채권(AA-이상)KIS액티브',
#     'nowVal': 101270,
#     'risefall': '2',
#     'changeVal': 190,
#     'changeRate': 0.19,
#     'nav': 101213.0,
#     'threeMonthEarnRate': 1.2497,
#     'quant': 2349,
#     'amonut': 237,
#     'marketSum': 6895},
#    {'itemcode': '462010',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 2차전지소재Fn',
#     'nowVal': 7000,
#     'risefall': '2',
#     'changeVal': 265,
#     'changeRate': 3.93,
#     'nav': 6989.0,
#     'threeMonthEarnRate': -12.4234,
#     'quant': 2889001,
#     'amonut': 20101,
#     'marketSum': 6815},
#    {'itemcode': '152100',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 200',
#     'nowVal': 37305,
#     'risefall': '2',
#     'changeVal': 390,
#     'changeRate': 1.06,
#     'nav': 37337.0,
#     'threeMonthEarnRate': 3.2235,
#     'quant': 913390,
#     'amonut': 34058,
#     'marketSum': 6491},
#    {'itemcode': '481050',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 1년은행양도성예금증서+액티브(합성)',
#     'nowVal': 1005255,
#     'risefall': '2',
#     'changeVal': 230,
#     'changeRate': 0.02,
#     'nav': 1005252.0,
#     'threeMonthEarnRate': None,
#     'quant': 10930,
#     'amonut': 10987,
#     'marketSum': 6149},
#    {'itemcode': '091180',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 자동차',
#     'nowVal': 21115,
#     'risefall': '2',
#     'changeVal': 270,
#     'changeRate': 1.3,
#     'nav': 21126.0,
#     'threeMonthEarnRate': -1.6077,
#     'quant': 343225,
#     'amonut': 7222,
#     'marketSum': 6144},
#    {'itemcode': '371160',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나항셍테크',
#     'nowVal': 5820,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.87,
#     'nav': 5781.0,
#     'threeMonthEarnRate': 19.0184,
#     'quant': 921277,
#     'amonut': 5363,
#     'marketSum': 6128},
#    {'itemcode': '091160',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 반도체',
#     'nowVal': 41595,
#     'risefall': '2',
#     'changeVal': 560,
#     'changeRate': 1.36,
#     'nav': 41616.0,
#     'threeMonthEarnRate': 8.4926,
#     'quant': 365775,
#     'amonut': 15182,
#     'marketSum': 6052},
#    {'itemcode': '329750',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국달러단기채권액티브',
#     'nowVal': 12190,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.33,
#     'nav': 12207.0,
#     'threeMonthEarnRate': 3.9215,
#     'quant': 75923,
#     'amonut': 924,
#     'marketSum': 5756},
#    {'itemcode': '114800',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 인버스',
#     'nowVal': 4200,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.94,
#     'nav': 4205.0,
#     'threeMonthEarnRate': -2.3256,
#     'quant': 25801765,
#     'amonut': 108623,
#     'marketSum': 5649},
#    {'itemcode': '446720',
#     'etfTabCode': 4,
#     'itemname': 'SOL 미국배당다우존스',
#     'nowVal': 10475,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.05,
#     'nav': 10457.0,
#     'threeMonthEarnRate': 3.5385,
#     'quant': 300280,
#     'amonut': 3141,
#     'marketSum': 5625},
#    {'itemcode': '196230',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 단기통안채',
#     'nowVal': 111765,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.03,
#     'nav': 111769.0,
#     'threeMonthEarnRate': 0.8345,
#     'quant': 39705,
#     'amonut': 4437,
#     'marketSum': 5507},
#    {'itemcode': '314250',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국빅테크10(H)',
#     'nowVal': 37655,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.03,
#     'nav': 37621.0,
#     'threeMonthEarnRate': 4.048,
#     'quant': 92572,
#     'amonut': 3491,
#     'marketSum': 5343},
#    {'itemcode': '293180',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 200',
#     'nowVal': 36865,
#     'risefall': '2',
#     'changeVal': 385,
#     'changeRate': 1.06,
#     'nav': 36894.0,
#     'threeMonthEarnRate': 3.243,
#     'quant': 110289,
#     'amonut': 4060,
#     'marketSum': 5235},
#    {'itemcode': '469830',
#     'etfTabCode': 6,
#     'itemname': 'SOL 초단기채권액티브',
#     'nowVal': 51330,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.03,
#     'nav': 51328.0,
#     'threeMonthEarnRate': 1.0632,
#     'quant': 80684,
#     'amonut': 4141,
#     'marketSum': 5118},
#    {'itemcode': '148070',
#     'etfTabCode': 6,
#     'itemname': 'KOSEF 국고채10년',
#     'nowVal': 112200,
#     'risefall': '2',
#     'changeVal': 350,
#     'changeRate': 0.31,
#     'nav': 112117.0,
#     'threeMonthEarnRate': 0.8766,
#     'quant': 6305,
#     'amonut': 706,
#     'marketSum': 5027},
#    {'itemcode': '368590',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국나스닥100',
#     'nowVal': 19025,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 0.4,
#     'nav': 18992.0,
#     'threeMonthEarnRate': 6.0124,
#     'quant': 136643,
#     'amonut': 2598,
#     'marketSum': 5004},
#    {'itemcode': '451540',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 종합채권(AA-이상)액티브',
#     'nowVal': 52970,
#     'risefall': '2',
#     'changeVal': 100,
#     'changeRate': 0.19,
#     'nav': 52959.0,
#     'threeMonthEarnRate': 1.2713,
#     'quant': 5498,
#     'amonut': 291,
#     'marketSum': 4926},
#    {'itemcode': '105190',
#     'etfTabCode': 1,
#     'itemname': 'ACE 200',
#     'nowVal': 37060,
#     'risefall': '2',
#     'changeVal': 430,
#     'changeRate': 1.17,
#     'nav': 37045.0,
#     'threeMonthEarnRate': 3.3002,
#     'quant': 25370,
#     'amonut': 940,
#     'marketSum': 4910},
#    {'itemcode': '329200',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 리츠부동산인프라',
#     'nowVal': 4610,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.44,
#     'nav': 4616.0,
#     'threeMonthEarnRate': 5.5644,
#     'quant': 985419,
#     'amonut': 4533,
#     'marketSum': 4640},
#    {'itemcode': '476550',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국30년국채프리미엄액티브(H)',
#     'nowVal': 9520,
#     'risefall': '2',
#     'changeVal': 85,
#     'changeRate': 0.9,
#     'nav': 9523.0,
#     'threeMonthEarnRate': -2.0879,
#     'quant': 1073175,
#     'amonut': 10220,
#     'marketSum': 4460},
#    {'itemcode': '458250',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국30년국채스트립액티브(합성 H)',
#     'nowVal': 43380,
#     'risefall': '2',
#     'changeVal': 780,
#     'changeRate': 1.83,
#     'nav': 43696.0,
#     'threeMonthEarnRate': -4.1538,
#     'quant': 138483,
#     'amonut': 6017,
#     'marketSum': 4298},
#    {'itemcode': '477080',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR CD금리액티브(합성)',
#     'nowVal': 100760,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.04,
#     'nav': 100703.0,
#     'threeMonthEarnRate': None,
#     'quant': 1624,
#     'amonut': 163,
#     'marketSum': 4235},
#    {'itemcode': '441680',
#     'etfTabCode': 7,
#     'itemname': 'TIGER 미국나스닥100커버드콜(합성)',
#     'nowVal': 10380,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.14,
#     'nav': 10410.0,
#     'threeMonthEarnRate': 3.7688,
#     'quant': 502082,
#     'amonut': 5212,
#     'marketSum': 4142},
#    {'itemcode': '278540',
#     'etfTabCode': 1,
#     'itemname': 'KODEX MSCI Korea TR',
#     'nowVal': 12470,
#     'risefall': '2',
#     'changeVal': 230,
#     'changeRate': 1.88,
#     'nav': 12435.0,
#     'threeMonthEarnRate': 2.1294,
#     'quant': 18734,
#     'amonut': 232,
#     'marketSum': 4140},
#    {'itemcode': '390390',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국반도체MV',
#     'nowVal': 22940,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.09,
#     'nav': 22831.0,
#     'threeMonthEarnRate': 12.6442,
#     'quant': 341268,
#     'amonut': 7809,
#     'marketSum': 4118},
#    {'itemcode': '379780',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국S&P500',
#     'nowVal': 15865,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.16,
#     'nav': 15849.0,
#     'threeMonthEarnRate': 6.7487,
#     'quant': 217547,
#     'amonut': 3446,
#     'marketSum': 4077},
#    {'itemcode': '385560',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KIS국고채30년Enhanced',
#     'nowVal': 71470,
#     'risefall': '2',
#     'changeVal': 385,
#     'changeRate': 0.54,
#     'nav': 71567.0,
#     'threeMonthEarnRate': 1.1935,
#     'quant': 37867,
#     'amonut': 2707,
#     'marketSum': 3945},
#    {'itemcode': '114260',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국고채3년',
#     'nowVal': 59800,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 0.11,
#     'nav': 59748.0,
#     'threeMonthEarnRate': 0.7582,
#     'quant': 2743,
#     'amonut': 164,
#     'marketSum': 3857},
#    {'itemcode': '365780',
#     'etfTabCode': 6,
#     'itemname': 'ACE 국고채10년',
#     'nowVal': 88175,
#     'risefall': '2',
#     'changeVal': 325,
#     'changeRate': 0.37,
#     'nav': 88129.0,
#     'threeMonthEarnRate': 0.8578,
#     'quant': 4248,
#     'amonut': 374,
#     'marketSum': 3857},
#    {'itemcode': '455850',
#     'etfTabCode': 2,
#     'itemname': 'SOL AI반도체소부장',
#     'nowVal': 15925,
#     'risefall': '2',
#     'changeVal': 180,
#     'changeRate': 1.14,
#     'nav': 15928.0,
#     'threeMonthEarnRate': 9.9261,
#     'quant': 651540,
#     'amonut': 10418,
#     'marketSum': 3854},
#    {'itemcode': '226490',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스피',
#     'nowVal': 27330,
#     'risefall': '2',
#     'changeVal': 275,
#     'changeRate': 1.02,
#     'nav': 27335.0,
#     'threeMonthEarnRate': 2.2026,
#     'quant': 77564,
#     'amonut': 2118,
#     'marketSum': 3758},
#    {'itemcode': '476450',
#     'etfTabCode': 6,
#     'itemname': '히어로즈 머니마켓액티브',
#     'nowVal': 50590,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.02,
#     'nav': 50590.0,
#     'threeMonthEarnRate': 1.0587,
#     'quant': 60333,
#     'amonut': 3052,
#     'marketSum': 3725},
#    {'itemcode': '251340',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 코스닥150선물인버스',
#     'nowVal': 3550,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -1.39,
#     'nav': 3562.0,
#     'threeMonthEarnRate': 1.7191,
#     'quant': 27630095,
#     'amonut': 98452,
#     'marketSum': 3550},
#    {'itemcode': '446770',
#     'etfTabCode': 4,
#     'itemname': 'ACE 글로벌반도체TOP4 Plus SOLACTIVE',
#     'nowVal': 24650,
#     'risefall': '2',
#     'changeVal': 120,
#     'changeRate': 0.49,
#     'nav': 24406.0,
#     'threeMonthEarnRate': 12.4287,
#     'quant': 379521,
#     'amonut': 9306,
#     'marketSum': 3525},
#    {'itemcode': '455030',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 미국달러SOFR금리액티브(합성)',
#     'nowVal': 11210,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.22,
#     'nav': 11236.0,
#     'threeMonthEarnRate': 4.4247,
#     'quant': 201615,
#     'amonut': 2264,
#     'marketSum': 3491},
#    {'itemcode': '251350',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 선진국MSCI World',
#     'nowVal': 27480,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.07,
#     'nav': 27376.0,
#     'threeMonthEarnRate': 6.9968,
#     'quant': 41021,
#     'amonut': 1125,
#     'marketSum': 3476},
#    {'itemcode': '402970',
#     'etfTabCode': 4,
#     'itemname': 'ACE 미국배당다우존스',
#     'nowVal': 11575,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.13,
#     'nav': 11555.0,
#     'threeMonthEarnRate': 3.6443,
#     'quant': 209857,
#     'amonut': 2426,
#     'marketSum': 3426},
#    {'itemcode': '364980',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 2차전지TOP10',
#     'nowVal': 11970,
#     'risefall': '2',
#     'changeVal': 550,
#     'changeRate': 4.82,
#     'nav': 11942.0,
#     'threeMonthEarnRate': -10.7982,
#     'quant': 1811543,
#     'amonut': 21539,
#     'marketSum': 3382},
#    {'itemcode': '467940',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 25-11 회사채(A+이상)액티브',
#     'nowVal': 10460,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 10465.0,
#     'threeMonthEarnRate': 1.1605,
#     'quant': 691,
#     'amonut': 7,
#     'marketSum': 3370},
#    {'itemcode': '273140',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기변동금리부채권액티브',
#     'nowVal': 110835,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.03,
#     'nav': 110827.0,
#     'threeMonthEarnRate': 0.9058,
#     'quant': 990,
#     'amonut': 109,
#     'marketSum': 3364},
#    {'itemcode': '394660',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌자율주행&전기차SOLACTIVE',
#     'nowVal': 11260,
#     'risefall': '5',
#     'changeVal': -130,
#     'changeRate': -1.14,
#     'nav': 11291.0,
#     'threeMonthEarnRate': 5.6285,
#     'quant': 24825,
#     'amonut': 279,
#     'marketSum': 3297},
#    {'itemcode': '302190',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 중장기국채',
#     'nowVal': 50400,
#     'risefall': '2',
#     'changeVal': 135,
#     'changeRate': 0.27,
#     'nav': 50384.0,
#     'threeMonthEarnRate': 0.7798,
#     'quant': 11159,
#     'amonut': 562,
#     'marketSum': 3286},
#    {'itemcode': '304660',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 미국30년국채울트라선물(H)',
#     'nowVal': 7945,
#     'risefall': '2',
#     'changeVal': 95,
#     'changeRate': 1.21,
#     'nav': 7935.0,
#     'threeMonthEarnRate': -1.549,
#     'quant': 276410,
#     'amonut': 2195,
#     'marketSum': 3281},
#    {'itemcode': '453870',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 인도니프티50',
#     'nowVal': 12475,
#     'risefall': '2',
#     'changeVal': 150,
#     'changeRate': 1.22,
#     'nav': 12485.0,
#     'threeMonthEarnRate': 1.9949,
#     'quant': 1371621,
#     'amonut': 16931,
#     'marketSum': 3275},
#    {'itemcode': '453810',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 인도Nifty50',
#     'nowVal': 12770,
#     'risefall': '2',
#     'changeVal': 180,
#     'changeRate': 1.43,
#     'nav': 12791.0,
#     'threeMonthEarnRate': 2.0294,
#     'quant': 2113938,
#     'amonut': 26732,
#     'marketSum': 3263},
#    {'itemcode': '161510',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 고배당주',
#     'nowVal': 13965,
#     'risefall': '2',
#     'changeVal': 45,
#     'changeRate': 0.32,
#     'nav': 13978.0,
#     'threeMonthEarnRate': 3.7518,
#     'quant': 543943,
#     'amonut': 7559,
#     'marketSum': 3167},
#    {'itemcode': '388420',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 비메모리반도체액티브',
#     'nowVal': 13885,
#     'risefall': '2',
#     'changeVal': 130,
#     'changeRate': 0.95,
#     'nav': 13922.0,
#     'threeMonthEarnRate': 9.9105,
#     'quant': 325153,
#     'amonut': 4532,
#     'marketSum': 3141},
#    {'itemcode': '479080',
#     'etfTabCode': 6,
#     'itemname': '1Q 머니마켓액티브',
#     'nowVal': 50415,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.03,
#     'nav': 50416.0,
#     'threeMonthEarnRate': None,
#     'quant': 19081,
#     'amonut': 962,
#     'marketSum': 3126},
#    {'itemcode': '474220',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국테크TOP10+10%프리미엄',
#     'nowVal': 11940,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.42,
#     'nav': 11897.0,
#     'threeMonthEarnRate': 13.5304,
#     'quant': 809866,
#     'amonut': 9652,
#     'marketSum': 3098},
#    {'itemcode': '069660',
#     'etfTabCode': 1,
#     'itemname': 'KOSEF 200',
#     'nowVal': 36720,
#     'risefall': '2',
#     'changeVal': 375,
#     'changeRate': 1.03,
#     'nav': 36745.0,
#     'threeMonthEarnRate': 3.2388,
#     'quant': 21573,
#     'amonut': 789,
#     'marketSum': 3048},
#    {'itemcode': '394670',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌리튬&2차전지SOLACTIVE(합성)',
#     'nowVal': 6660,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.22,
#     'nav': 6684.0,
#     'threeMonthEarnRate': -1.1136,
#     'quant': 61859,
#     'amonut': 412,
#     'marketSum': 2981},
#    {'itemcode': '241180',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 일본니케이225',
#     'nowVal': 20555,
#     'risefall': '5',
#     'changeVal': -165,
#     'changeRate': -0.8,
#     'nav': 20529.0,
#     'threeMonthEarnRate': -3.9935,
#     'quant': 197740,
#     'amonut': 4057,
#     'marketSum': 2980},
#    {'itemcode': '472870',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 미국30년국채엔화노출(합성 H)',
#     'nowVal': 8785,
#     'risefall': '2',
#     'changeVal': 105,
#     'changeRate': 1.21,
#     'nav': 8772.0,
#     'threeMonthEarnRate': -3.3235,
#     'quant': 611018,
#     'amonut': 5378,
#     'marketSum': 2956},
#    {'itemcode': '439870',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국고채30년액티브',
#     'nowVal': 106765,
#     'risefall': '2',
#     'changeVal': 555,
#     'changeRate': 0.52,
#     'nav': 106898.0,
#     'threeMonthEarnRate': 1.4201,
#     'quant': 5645,
#     'amonut': 602,
#     'marketSum': 2951},
#    {'itemcode': '245710',
#     'etfTabCode': 4,
#     'itemname': 'ACE 베트남VN30(합성)',
#     'nowVal': 19965,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.15,
#     'nav': 20199.0,
#     'threeMonthEarnRate': 2.6478,
#     'quant': 69231,
#     'amonut': 1382,
#     'marketSum': 2855},
#    {'itemcode': '456610',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국달러SOFR금리액티브(합성)',
#     'nowVal': 54200,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.06,
#     'nav': 54202.0,
#     'threeMonthEarnRate': 4.1706,
#     'quant': 5755,
#     'amonut': 311,
#     'marketSum': 2842},
#    {'itemcode': '091170',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 은행',
#     'nowVal': 7870,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.06,
#     'nav': 7868.0,
#     'threeMonthEarnRate': 1.3522,
#     'quant': 550733,
#     'amonut': 4307,
#     'marketSum': 2821},
#    {'itemcode': '439860',
#     'etfTabCode': 6,
#     'itemname': 'KODEX ESG종합채권(A-이상)액티브',
#     'nowVal': 109585,
#     'risefall': '2',
#     'changeVal': 380,
#     'changeRate': 0.35,
#     'nav': 109578.0,
#     'threeMonthEarnRate': 1.2192,
#     'quant': 200,
#     'amonut': 21,
#     'marketSum': 2805},
#    {'itemcode': '457480',
#     'etfTabCode': 4,
#     'itemname': 'ACE 테슬라밸류체인액티브',
#     'nowVal': 10150,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.25,
#     'nav': 10125.0,
#     'threeMonthEarnRate': -3.1951,
#     'quant': 221063,
#     'amonut': 2240,
#     'marketSum': 2771},
#    {'itemcode': '361580',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 200TR',
#     'nowVal': 20175,
#     'risefall': '2',
#     'changeVal': 260,
#     'changeRate': 1.31,
#     'nav': 20151.0,
#     'threeMonthEarnRate': 3.4085,
#     'quant': 9798,
#     'amonut': 196,
#     'marketSum': 2764},
#    {'itemcode': '143860',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 헬스케어',
#     'nowVal': 32305,
#     'risefall': '2',
#     'changeVal': 210,
#     'changeRate': 0.65,
#     'nav': 32376.0,
#     'threeMonthEarnRate': 0.4602,
#     'quant': 67430,
#     'amonut': 2171,
#     'marketSum': 2746},
#    {'itemcode': '465580',
#     'etfTabCode': 4,
#     'itemname': 'ACE 미국빅테크TOP7 Plus',
#     'nowVal': 14250,
#     'risefall': '2',
#     'changeVal': 85,
#     'changeRate': 0.6,
#     'nav': 14174.0,
#     'threeMonthEarnRate': 14.4118,
#     'quant': 343269,
#     'amonut': 4883,
#     'marketSum': 2651},
#    {'itemcode': '461460',
#     'etfTabCode': 6,
#     'itemname': 'ARIRANG 국고채10년액티브',
#     'nowVal': 52415,
#     'risefall': '2',
#     'changeVal': 170,
#     'changeRate': 0.33,
#     'nav': 52378.0,
#     'threeMonthEarnRate': 0.7786,
#     'quant': 149,
#     'amonut': 7,
#     'marketSum': 2635},
#    {'itemcode': '466940',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 은행고배당플러스TOP10',
#     'nowVal': 12850,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.35,
#     'nav': 12844.0,
#     'threeMonthEarnRate': 2.8411,
#     'quant': 415508,
#     'amonut': 5320,
#     'marketSum': 2596},
#    {'itemcode': '091230',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 반도체',
#     'nowVal': 43135,
#     'risefall': '2',
#     'changeVal': 405,
#     'changeRate': 0.95,
#     'nav': 43125.0,
#     'threeMonthEarnRate': 7.9724,
#     'quant': 170385,
#     'amonut': 7333,
#     'marketSum': 2562},
#    {'itemcode': '451000',
#     'etfTabCode': 6,
#     'itemname': 'ARIRANG 종합채권(AA-이상)액티브',
#     'nowVal': 107910,
#     'risefall': '2',
#     'changeVal': 210,
#     'changeRate': 0.19,
#     'nav': 107786.0,
#     'threeMonthEarnRate': 1.3144,
#     'quant': 34,
#     'amonut': 3,
#     'marketSum': 2540},
#    {'itemcode': '449180',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국S&P500(H)',
#     'nowVal': 12465,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.32,
#     'nav': 12453.0,
#     'threeMonthEarnRate': 3.187,
#     'quant': 83195,
#     'amonut': 1037,
#     'marketSum': 2487},
#    {'itemcode': '464540',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 25-03 회사채(AA-이상)액티브',
#     'nowVal': 50935,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.01,
#     'nav': 50936.0,
#     'threeMonthEarnRate': 1.0474,
#     'quant': 223,
#     'amonut': 11,
#     'marketSum': 2471},
#    {'itemcode': '367770',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR Fn수소경제테마',
#     'nowVal': 9640,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.52,
#     'nav': 9645.0,
#     'threeMonthEarnRate': 4.0138,
#     'quant': 56088,
#     'amonut': 539,
#     'marketSum': 2381},
#    {'itemcode': '448880',
#     'etfTabCode': 6,
#     'itemname': 'ACE 24-12 회사채(AA-이상)액티브',
#     'nowVal': 104545,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.03,
#     'nav': 104544.0,
#     'threeMonthEarnRate': 1.0877,
#     'quant': 3298,
#     'amonut': 344,
#     'marketSum': 2375},
#    {'itemcode': '473290',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 26-12 회사채(AA-이상)액티브',
#     'nowVal': 10285,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.1,
#     'nav': 10283.0,
#     'threeMonthEarnRate': 1.33,
#     'quant': 38805,
#     'amonut': 398,
#     'marketSum': 2365},
#    {'itemcode': '192090',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나CSI300',
#     'nowVal': 8890,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.45,
#     'nav': 8910.0,
#     'threeMonthEarnRate': 3.252,
#     'quant': 3310379,
#     'amonut': 29478,
#     'marketSum': 2356},
#    {'itemcode': '290130',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR ESG사회책임투자',
#     'nowVal': 12300,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.41,
#     'nav': 12335.0,
#     'threeMonthEarnRate': 1.343,
#     'quant': 4887,
#     'amonut': 59,
#     'marketSum': 2337},
#    {'itemcode': '456600',
#     'etfTabCode': 4,
#     'itemname': 'TIMEFOLIO 글로벌AI인공지능액티브',
#     'nowVal': 20155,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.2,
#     'nav': 20162.0,
#     'threeMonthEarnRate': 9.1524,
#     'quant': 113973,
#     'amonut': 2299,
#     'marketSum': 2310},
#    {'itemcode': '422420',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 2차전지액티브',
#     'nowVal': 9795,
#     'risefall': '2',
#     'changeVal': 315,
#     'changeRate': 3.32,
#     'nav': 9795.0,
#     'threeMonthEarnRate': -7.2883,
#     'quant': 74222,
#     'amonut': 726,
#     'marketSum': 2296},
#    {'itemcode': '471990',
#     'etfTabCode': 2,
#     'itemname': 'KODEX AI반도체핵심장비',
#     'nowVal': 13930,
#     'risefall': '2',
#     'changeVal': 140,
#     'changeRate': 1.02,
#     'nav': 13951.0,
#     'threeMonthEarnRate': 17.3843,
#     'quant': 2095645,
#     'amonut': 29310,
#     'marketSum': 2285},
#    {'itemcode': '411060',
#     'etfTabCode': 5,
#     'itemname': 'ACE KRX금현물',
#     'nowVal': 14710,
#     'risefall': '5',
#     'changeVal': -125,
#     'changeRate': -0.84,
#     'nav': 14647.0,
#     'threeMonthEarnRate': 13.503,
#     'quant': 175780,
#     'amonut': 2588,
#     'marketSum': 2280},
#    {'itemcode': '448290',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500TR(H)',
#     'nowVal': 12825,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.39,
#     'nav': 12813.0,
#     'threeMonthEarnRate': 3.2608,
#     'quant': 60873,
#     'amonut': 780,
#     'marketSum': 2257},
#    {'itemcode': '295040',
#     'etfTabCode': 1,
#     'itemname': 'SOL 200TR',
#     'nowVal': 13300,
#     'risefall': '2',
#     'changeVal': 130,
#     'changeRate': 0.99,
#     'nav': 13308.0,
#     'threeMonthEarnRate': 3.2207,
#     'quant': 13950,
#     'amonut': 185,
#     'marketSum': 2254},
#    {'itemcode': '423920',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국필라델피아반도체레버리지(합성)',
#     'nowVal': 26215,
#     'risefall': '5',
#     'changeVal': -135,
#     'changeRate': -0.51,
#     'nav': 25898.0,
#     'threeMonthEarnRate': 10.6585,
#     'quant': 274711,
#     'amonut': 7148,
#     'marketSum': 2252},
#    {'itemcode': '449190',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국나스닥100(H)',
#     'nowVal': 14855,
#     'risefall': '2',
#     'changeVal': 85,
#     'changeRate': 0.58,
#     'nav': 14830.0,
#     'threeMonthEarnRate': 2.42,
#     'quant': 105171,
#     'amonut': 1563,
#     'marketSum': 2176},
#    {'itemcode': '200250',
#     'etfTabCode': 4,
#     'itemname': 'KOSEF 인도Nifty50(합성)',
#     'nowVal': 23445,
#     'risefall': '2',
#     'changeVal': 250,
#     'changeRate': 1.08,
#     'nav': 23459.0,
#     'threeMonthEarnRate': 1.2742,
#     'quant': 133666,
#     'amonut': 3100,
#     'marketSum': 2157},
#    {'itemcode': '462330',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 2차전지산업레버리지',
#     'nowVal': 3500,
#     'risefall': '2',
#     'changeVal': 240,
#     'changeRate': 7.36,
#     'nav': 3502.0,
#     'threeMonthEarnRate': -20.1825,
#     'quant': 6966652,
#     'amonut': 24062,
#     'marketSum': 2128},
#    {'itemcode': '278620',
#     'etfTabCode': 6,
#     'itemname': 'ARIRANG 단기채권액티브',
#     'nowVal': 113230,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.03,
#     'nav': 113235.0,
#     'threeMonthEarnRate': 0.9719,
#     'quant': 47,
#     'amonut': 5,
#     'marketSum': 2108},
#    {'itemcode': '471230',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국고채10년액티브',
#     'nowVal': 106340,
#     'risefall': '2',
#     'changeVal': 360,
#     'changeRate': 0.34,
#     'nav': 106317.0,
#     'threeMonthEarnRate': 0.8487,
#     'quant': 6162,
#     'amonut': 655,
#     'marketSum': 2101},
#    {'itemcode': '466920',
#     'etfTabCode': 2,
#     'itemname': 'SOL 조선TOP3플러스',
#     'nowVal': 10255,
#     'risefall': '5',
#     'changeVal': -105,
#     'changeRate': -1.01,
#     'nav': 10249.0,
#     'threeMonthEarnRate': 19.2441,
#     'quant': 452079,
#     'amonut': 4648,
#     'marketSum': 2087},
#    {'itemcode': '372330',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 차이나항셍테크',
#     'nowVal': 5825,
#     'risefall': '2',
#     'changeVal': 45,
#     'changeRate': 0.78,
#     'nav': 5773.0,
#     'threeMonthEarnRate': 18.1541,
#     'quant': 197644,
#     'amonut': 1150,
#     'marketSum': 1966},
#    {'itemcode': '455860',
#     'etfTabCode': 2,
#     'itemname': 'SOL 2차전지소부장Fn',
#     'nowVal': 6625,
#     'risefall': '2',
#     'changeVal': 250,
#     'changeRate': 3.92,
#     'nav': 6622.0,
#     'threeMonthEarnRate': -13.5569,
#     'quant': 1151803,
#     'amonut': 7613,
#     'marketSum': 1944},
#    {'itemcode': '477050',
#     'etfTabCode': 6,
#     'itemname': 'ARIRANG 머니마켓액티브',
#     'nowVal': 50405,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.03,
#     'nav': 50410.0,
#     'threeMonthEarnRate': None,
#     'quant': 5708,
#     'amonut': 287,
#     'marketSum': 1939},
#    {'itemcode': '409820',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국나스닥100레버리지(합성 H)',
#     'nowVal': 10100,
#     'risefall': '2',
#     'changeVal': 115,
#     'changeRate': 1.15,
#     'nav': 10068.0,
#     'threeMonthEarnRate': 3.696,
#     'quant': 198855,
#     'amonut': 2008,
#     'marketSum': 1914},
#    {'itemcode': '143850',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500선물(H)',
#     'nowVal': 58605,
#     'risefall': '2',
#     'changeVal': 185,
#     'changeRate': 0.32,
#     'nav': 58574.0,
#     'threeMonthEarnRate': 2.51,
#     'quant': 71596,
#     'amonut': 4196,
#     'marketSum': 1875},
#    {'itemcode': '272560',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 단기국공채액티브',
#     'nowVal': 109220,
#     'risefall': '2',
#     'changeVal': 45,
#     'changeRate': 0.04,
#     'nav': 109214.0,
#     'threeMonthEarnRate': 0.9473,
#     'quant': 308,
#     'amonut': 33,
#     'marketSum': 1859},
#    {'itemcode': '451600',
#     'etfTabCode': 6,
#     'itemname': 'ARIRANG 국고채30년액티브',
#     'nowVal': 102480,
#     'risefall': '2',
#     'changeVal': 625,
#     'changeRate': 0.61,
#     'nav': 102324.0,
#     'threeMonthEarnRate': 1.4703,
#     'quant': 75,
#     'amonut': 7,
#     'marketSum': 1853},
#    {'itemcode': '332940',
#     'etfTabCode': 1,
#     'itemname': 'HANARO MSCI Korea TR',
#     'nowVal': 15545,
#     'risefall': '2',
#     'changeVal': 150,
#     'changeRate': 0.97,
#     'nav': 15592.0,
#     'threeMonthEarnRate': 1.3363,
#     'quant': 80,
#     'amonut': 1,
#     'marketSum': 1850},
#    {'itemcode': '463290',
#     'etfTabCode': 6,
#     'itemname': '1Q 단기금융채액티브',
#     'nowVal': 103775,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.03,
#     'nav': 103774.0,
#     'threeMonthEarnRate': 1.0664,
#     'quant': 21005,
#     'amonut': 2179,
#     'marketSum': 1847},
#    {'itemcode': '328370',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 코스피TR',
#     'nowVal': 14525,
#     'risefall': '2',
#     'changeVal': 160,
#     'changeRate': 1.11,
#     'nav': 14508.0,
#     'threeMonthEarnRate': 1.9656,
#     'quant': 25,
#     'amonut': 0,
#     'marketSum': 1845},
#    {'itemcode': '471760',
#     'etfTabCode': 2,
#     'itemname': 'TIGER AI반도체핵심공정',
#     'nowVal': 13300,
#     'risefall': '2',
#     'changeVal': 255,
#     'changeRate': 1.95,
#     'nav': 13307.0,
#     'threeMonthEarnRate': 15.1116,
#     'quant': 1134003,
#     'amonut': 15087,
#     'marketSum': 1842},
#    {'itemcode': '395270',
#     'etfTabCode': 2,
#     'itemname': 'HANARO Fn K-반도체',
#     'nowVal': 12065,
#     'risefall': '2',
#     'changeVal': 130,
#     'changeRate': 1.09,
#     'nav': 12053.0,
#     'threeMonthEarnRate': 11.5683,
#     'quant': 145584,
#     'amonut': 1749,
#     'marketSum': 1822},
#    {'itemcode': '469820',
#     'etfTabCode': 6,
#     'itemname': 'SOL 24-12 회사채(AA-이상)액티브',
#     'nowVal': 51500,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.01,
#     'nav': 51510.0,
#     'threeMonthEarnRate': 1.0497,
#     'quant': 6453,
#     'amonut': 332,
#     'marketSum': 1805},
#    {'itemcode': '473330',
#     'etfTabCode': 6,
#     'itemname': 'SOL 미국30년국채커버드콜(합성)',
#     'nowVal': 9920,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 0.66,
#     'nav': 9945.0,
#     'threeMonthEarnRate': 1.9632,
#     'quant': 506572,
#     'amonut': 5028,
#     'marketSum': 1676},
#    {'itemcode': '445290',
#     'etfTabCode': 2,
#     'itemname': 'KODEX K-로봇액티브',
#     'nowVal': 13980,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 0.54,
#     'nav': 13974.0,
#     'threeMonthEarnRate': -2.8222,
#     'quant': 33273,
#     'amonut': 464,
#     'marketSum': 1671},
#    {'itemcode': '464230',
#     'etfTabCode': 6,
#     'itemname': '히어로즈 24-09 회사채(AA-이상)액티브',
#     'nowVal': 51405,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.03,
#     'nav': 51411.0,
#     'threeMonthEarnRate': 0.9723,
#     'quant': 603,
#     'amonut': 30,
#     'marketSum': 1655},
#    {'itemcode': '452360',
#     'etfTabCode': 4,
#     'itemname': 'SOL 미국배당다우존스(H)',
#     'nowVal': 10745,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.28,
#     'nav': 10726.0,
#     'threeMonthEarnRate': 0.0931,
#     'quant': 76131,
#     'amonut': 817,
#     'marketSum': 1644},
#    {'itemcode': '329650',
#     'etfTabCode': 7,
#     'itemname': 'KODEX TRF3070',
#     'nowVal': 12575,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.04,
#     'nav': 12586.0,
#     'threeMonthEarnRate': 2.9471,
#     'quant': 37109,
#     'amonut': 466,
#     'marketSum': 1610},
#    {'itemcode': '438330',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 투자등급회사채액티브',
#     'nowVal': 110460,
#     'risefall': '2',
#     'changeVal': 150,
#     'changeRate': 0.14,
#     'nav': 110479.0,
#     'threeMonthEarnRate': 1.535,
#     'quant': 4565,
#     'amonut': 504,
#     'marketSum': 1606},
#    {'itemcode': '363570',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 장기종합채권(AA-이상)액티브KAP',
#     'nowVal': 93400,
#     'risefall': '2',
#     'changeVal': 275,
#     'changeRate': 0.3,
#     'nav': 93412.0,
#     'threeMonthEarnRate': 1.3674,
#     'quant': 14,
#     'amonut': 1,
#     'marketSum': 1592},
#    {'itemcode': '326240',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR IT플러스',
#     'nowVal': 18455,
#     'risefall': '2',
#     'changeVal': 305,
#     'changeRate': 1.68,
#     'nav': 18460.0,
#     'threeMonthEarnRate': 2.5277,
#     'quant': 13142,
#     'amonut': 241,
#     'marketSum': 1591},
#    {'itemcode': '475080',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 테슬라인컴프리미엄채권혼합액티브',
#     'nowVal': 9420,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.16,
#     'nav': 9390.0,
#     'threeMonthEarnRate': -0.4755,
#     'quant': 289384,
#     'amonut': 2723,
#     'marketSum': 1578},
#    {'itemcode': '364960',
#     'etfTabCode': 2,
#     'itemname': 'TIGER BBIG',
#     'nowVal': 6090,
#     'risefall': '2',
#     'changeVal': 105,
#     'changeRate': 1.75,
#     'nav': 6085.0,
#     'threeMonthEarnRate': 0.3294,
#     'quant': 210672,
#     'amonut': 1282,
#     'marketSum': 1565},
#    {'itemcode': '132030',
#     'etfTabCode': 5,
#     'itemname': 'KODEX 골드선물(H)',
#     'nowVal': 14490,
#     'risefall': '5',
#     'changeVal': -110,
#     'changeRate': -0.75,
#     'nav': 14498.0,
#     'threeMonthEarnRate': 9.0703,
#     'quant': 76491,
#     'amonut': 1108,
#     'marketSum': 1536},
#    {'itemcode': '451530',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 국고채30년스트립액티브',
#     'nowVal': 50590,
#     'risefall': '2',
#     'changeVal': 340,
#     'changeRate': 0.68,
#     'nav': 50680.0,
#     'threeMonthEarnRate': 1.4437,
#     'quant': 31499,
#     'amonut': 1594,
#     'marketSum': 1520},
#    {'itemcode': '462900',
#     'etfTabCode': 2,
#     'itemname': 'KoAct 바이오헬스케어액티브',
#     'nowVal': 11570,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 11587.0,
#     'threeMonthEarnRate': 7.0701,
#     'quant': 225694,
#     'amonut': 2607,
#     'marketSum': 1510},
#    {'itemcode': '476070',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 글로벌비만치료제TOP2 Plus',
#     'nowVal': 11965,
#     'risefall': '5',
#     'changeVal': -165,
#     'changeRate': -1.36,
#     'nav': 12068.0,
#     'threeMonthEarnRate': -0.9602,
#     'quant': 333183,
#     'amonut': 3998,
#     'marketSum': 1484},
#    {'itemcode': '292560',
#     'etfTabCode': 7,
#     'itemname': 'TIGER 일본엔선물',
#     'nowVal': 8400,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.24,
#     'nav': 8408.0,
#     'threeMonthEarnRate': -1.0601,
#     'quant': 226799,
#     'amonut': 1909,
#     'marketSum': 1478},
#    {'itemcode': '451060',
#     'etfTabCode': 1,
#     'itemname': '1Q K200액티브',
#     'nowVal': 11635,
#     'risefall': '2',
#     'changeVal': 100,
#     'changeRate': 0.87,
#     'nav': 11665.0,
#     'threeMonthEarnRate': 2.8735,
#     'quant': 52201,
#     'amonut': 608,
#     'marketSum': 1466},
#    {'itemcode': '448300',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국나스닥100TR(H)',
#     'nowVal': 15240,
#     'risefall': '2',
#     'changeVal': 90,
#     'changeRate': 0.59,
#     'nav': 15216.0,
#     'threeMonthEarnRate': 2.4882,
#     'quant': 68975,
#     'amonut': 1051,
#     'marketSum': 1463},
#    {'itemcode': '461950',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 2차전지핵심소재10 Fn',
#     'nowVal': 7145,
#     'risefall': '2',
#     'changeVal': 315,
#     'changeRate': 4.61,
#     'nav': 7139.0,
#     'threeMonthEarnRate': -15.3838,
#     'quant': 1064519,
#     'amonut': 7575,
#     'marketSum': 1461},
#    {'itemcode': '261260',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 미국달러선물인버스2X',
#     'nowVal': 5950,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.51,
#     'nav': 5951.0,
#     'threeMonthEarnRate': -6.373,
#     'quant': 528631,
#     'amonut': 3147,
#     'marketSum': 1429},
#    {'itemcode': '244580',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 바이오',
#     'nowVal': 8015,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.25,
#     'nav': 8064.0,
# ...
#     'nowVal': 8430,
#     'risefall': '2',
#     'changeVal': 135,
#     'changeRate': 1.63,
#     'nav': 8475.0,
#     'threeMonthEarnRate': -0.3547,
#     'quant': 294,
#     'amonut': 2,
#     'marketSum': 42},
#    {'itemcode': '407170',
#     'etfTabCode': 2,
#     'itemname': 'KCGI 스마트커머스액티브',
#     'nowVal': 8410,
#     'risefall': '2',
#     'changeVal': 90,
#     'changeRate': 1.08,
#     'nav': 8413.0,
#     'threeMonthEarnRate': 23.0431,
#     'quant': 203,
#     'amonut': 1,
#     'marketSum': 42},
#    {'itemcode': '438210',
#     'etfTabCode': 4,
#     'itemname': 'ARIRANG 글로벌인공지능산업MV',
#     'nowVal': 11615,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.17,
#     'nav': 11646.0,
#     'threeMonthEarnRate': -11.0303,
#     'quant': 2797,
#     'amonut': 32,
#     'marketSum': 41},
#    {'itemcode': '465620',
#     'etfTabCode': 4,
#     'itemname': 'ACE 미국빅테크TOP7 Plus인버스(합성)',
#     'nowVal': 13460,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.3,
#     'nav': 13437.0,
#     'threeMonthEarnRate': -13.3012,
#     'quant': 335,
#     'amonut': 4,
#     'marketSum': 40},
#    {'itemcode': '445930',
#     'etfTabCode': 4,
#     'itemname': 'KOSEF 차이나A50커넥트레버리지MSCI(합성H)',
#     'nowVal': 8015,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 8370.0,
#     'threeMonthEarnRate': 10.8575,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 40},
#    {'itemcode': '284990',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200에너지화학',
#     'nowVal': 8315,
#     'risefall': '2',
#     'changeVal': 45,
#     'changeRate': 0.54,
#     'nav': 8322.0,
#     'threeMonthEarnRate': -8.4554,
#     'quant': 19055,
#     'amonut': 158,
#     'marketSum': 40},
#    {'itemcode': '256450',
#     'etfTabCode': 4,
#     'itemname': 'ARIRANG 심천차이넥스트(합성)',
#     'nowVal': 7850,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.06,
#     'nav': 7870.0,
#     'threeMonthEarnRate': 2.2135,
#     'quant': 91,
#     'amonut': 0,
#     'marketSum': 39},
#    {'itemcode': '295000',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 국채선물10년',
#     'nowVal': 52385,
#     'risefall': '2',
#     'changeVal': 215,
#     'changeRate': 0.41,
#     'nav': 52383.0,
#     'threeMonthEarnRate': 0.4506,
#     'quant': 334,
#     'amonut': 17,
#     'marketSum': 39},
#    {'itemcode': '139310',
#     'etfTabCode': 5,
#     'itemname': 'TIGER 금속선물(H)',
#     'nowVal': 6390,
#     'risefall': '5',
#     'changeVal': -75,
#     'changeRate': -1.16,
#     'nav': 6353.0,
#     'threeMonthEarnRate': 17.2477,
#     'quant': 5576,
#     'amonut': 35,
#     'marketSum': 38},
#    {'itemcode': '215620',
#     'etfTabCode': 2,
#     'itemname': 'HK S&P코리아로우볼',
#     'nowVal': 12765,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 12780.0,
#     'threeMonthEarnRate': -1.1844,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 38},
#    {'itemcode': '322410',
#     'etfTabCode': 2,
#     'itemname': 'HANARO 고배당',
#     'nowVal': 12745,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 12737.0,
#     'threeMonthEarnRate': -0.6858,
#     'quant': 289,
#     'amonut': 3,
#     'marketSum': 38},
#    {'itemcode': '427120',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR Fn플랫폼테마',
#     'nowVal': 6500,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.76,
#     'nav': 6494.0,
#     'threeMonthEarnRate': -8.1921,
#     'quant': 619,
#     'amonut': 4,
#     'marketSum': 38},
#    {'itemcode': '407300',
#     'etfTabCode': 2,
#     'itemname': 'HANARO Fn골프테마',
#     'nowVal': 5760,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.44,
#     'nav': 5748.0,
#     'threeMonthEarnRate': -3.4044,
#     'quant': 10879,
#     'amonut': 62,
#     'marketSum': 37},
#    {'itemcode': '469790',
#     'etfTabCode': 2,
#     'itemname': 'KOSEF K-테크TOP10',
#     'nowVal': 11625,
#     'risefall': '2',
#     'changeVal': 80,
#     'changeRate': 0.69,
#     'nav': 11636.0,
#     'threeMonthEarnRate': 5.156,
#     'quant': 365,
#     'amonut': 4,
#     'marketSum': 35},
#    {'itemcode': '291620',
#     'etfTabCode': 3,
#     'itemname': 'KOSEF 코스닥150선물인버스',
#     'nowVal': 6400,
#     'risefall': '5',
#     'changeVal': -75,
#     'changeRate': -1.16,
#     'nav': 6388.0,
#     'threeMonthEarnRate': 2.0733,
#     'quant': 2552,
#     'amonut': 16,
#     'marketSum': 34},
#    {'itemcode': '243890',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200에너지화학레버리지',
#     'nowVal': 6350,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.24,
#     'nav': 6345.0,
#     'threeMonthEarnRate': -18.2755,
#     'quant': 25067,
#     'amonut': 159,
#     'marketSum': 33},
#    {'itemcode': '098560',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 방송통신',
#     'nowVal': 6665,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.45,
#     'nav': 6665.0,
#     'threeMonthEarnRate': -6.718,
#     'quant': 8688,
#     'amonut': 57,
#     'marketSum': 33},
#    {'itemcode': '426410',
#     'etfTabCode': 4,
#     'itemname': 'ARIRANG 미국대체투자Top10MV',
#     'nowVal': 16565,
#     'risefall': '5',
#     'changeVal': -90,
#     'changeRate': -0.54,
#     'nav': 16450.0,
#     'threeMonthEarnRate': 6.0092,
#     'quant': 40,
#     'amonut': 0,
#     'marketSum': 33},
#    {'itemcode': '220130',
#     'etfTabCode': 4,
#     'itemname': 'SOL 차이나강소기업CSI500(합성 H)',
#     'nowVal': 4130,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.6,
#     'nav': 4118.0,
#     'threeMonthEarnRate': -1.3143,
#     'quant': 484,
#     'amonut': 2,
#     'marketSum': 33},
#    {'itemcode': '334700',
#     'etfTabCode': 5,
#     'itemname': 'KBSTAR 팔라듐선물인버스(H)',
#     'nowVal': 6600,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 6665.0,
#     'threeMonthEarnRate': 0.4566,
#     'quant': 128,
#     'amonut': 0,
#     'marketSum': 33},
#    {'itemcode': '397420',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 국채선물5년추종',
#     'nowVal': 49700,
#     'risefall': '2',
#     'changeVal': 190,
#     'changeRate': 0.38,
#     'nav': 49661.0,
#     'threeMonthEarnRate': 0.5462,
#     'quant': 34,
#     'amonut': 1,
#     'marketSum': 33},
#    {'itemcode': '322130',
#     'etfTabCode': 2,
#     'itemname': 'ACE 스마트로우볼',
#     'nowVal': 16305,
#     'risefall': '2',
#     'changeVal': 115,
#     'changeRate': 0.71,
#     'nav': 16264.0,
#     'threeMonthEarnRate': 2.0465,
#     'quant': 20,
#     'amonut': 0,
#     'marketSum': 33},
#    {'itemcode': '285010',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200중공업',
#     'nowVal': 13470,
#     'risefall': '5',
#     'changeVal': -195,
#     'changeRate': -1.43,
#     'nav': 13450.0,
#     'threeMonthEarnRate': 27.6414,
#     'quant': 5889,
#     'amonut': 79,
#     'marketSum': 32},
#    {'itemcode': '285020',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200철강소재',
#     'nowVal': 8445,
#     'risefall': '2',
#     'changeVal': 70,
#     'changeRate': 0.84,
#     'nav': 8473.0,
#     'threeMonthEarnRate': -3.5849,
#     'quant': 13503,
#     'amonut': 114,
#     'marketSum': 32},
#    {'itemcode': '456100',
#     'etfTabCode': 6,
#     'itemname': 'HANARO 유로존국채25년플러스(합성 H)',
#     'nowVal': 50090,
#     'risefall': '2',
#     'changeVal': 120,
#     'changeRate': 0.24,
#     'nav': 50331.0,
#     'threeMonthEarnRate': -1.5914,
#     'quant': 191,
#     'amonut': 9,
#     'marketSum': 32},
#    {'itemcode': '472490',
#     'etfTabCode': 4,
#     'itemname': 'HANARO 미국애그테크',
#     'nowVal': 10575,
#     'risefall': '5',
#     'changeVal': -100,
#     'changeRate': -0.94,
#     'nav': 10650.0,
#     'threeMonthEarnRate': 4.6097,
#     'quant': 493,
#     'amonut': 5,
#     'marketSum': 32},
#    {'itemcode': '266550',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 중형주저변동50',
#     'nowVal': 12420,
#     'risefall': '5',
#     'changeVal': -60,
#     'changeRate': -0.48,
#     'nav': 12411.0,
#     'threeMonthEarnRate': 13.8509,
#     'quant': 309,
#     'amonut': 3,
#     'marketSum': 31},
#    {'itemcode': '267500',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 미국장기국채선물인버스2X(합성 H)',
#     'nowVal': 10175,
#     'risefall': '5',
#     'changeVal': -225,
#     'changeRate': -2.16,
#     'nav': 10301.0,
#     'threeMonthEarnRate': 0.7425,
#     'quant': 866,
#     'amonut': 8,
#     'marketSum': 31},
#    {'itemcode': '301410',
#     'etfTabCode': 3,
#     'itemname': 'ARIRANG 코스닥150선물인버스',
#     'nowVal': 5475,
#     'risefall': '5',
#     'changeVal': -85,
#     'changeRate': -1.53,
#     'nav': 5505.0,
#     'threeMonthEarnRate': 1.7657,
#     'quant': 1312,
#     'amonut': 7,
#     'marketSum': 30},
#    {'itemcode': '287300',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200건설',
#     'nowVal': 12525,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.16,
#     'nav': 12472.0,
#     'threeMonthEarnRate': -7.4006,
#     'quant': 66,
#     'amonut': 0,
#     'marketSum': 30},
#    {'itemcode': '272230',
#     'etfTabCode': 2,
#     'itemname': 'ACE 스마트밸류',
#     'nowVal': 14755,
#     'risefall': '2',
#     'changeVal': 195,
#     'changeRate': 1.34,
#     'nav': 14715.0,
#     'threeMonthEarnRate': 4.8685,
#     'quant': 22,
#     'amonut': 0,
#     'marketSum': 30},
#    {'itemcode': '253240',
#     'etfTabCode': 3,
#     'itemname': 'KOSEF 200선물인버스',
#     'nowVal': 5435,
#     'risefall': '5',
#     'changeVal': -60,
#     'changeRate': -1.09,
#     'nav': 5436.0,
#     'threeMonthEarnRate': -2.1603,
#     'quant': 20730,
#     'amonut': 113,
#     'marketSum': 28},
#    {'itemcode': '473500',
#     'etfTabCode': 4,
#     'itemname': 'KOSEF 글로벌전력반도체',
#     'nowVal': 9350,
#     'risefall': '5',
#     'changeVal': -140,
#     'changeRate': -1.48,
#     'nav': 9494.0,
#     'threeMonthEarnRate': -1.5272,
#     'quant': 25158,
#     'amonut': 236,
#     'marketSum': 28},
#    {'itemcode': '306530',
#     'etfTabCode': 3,
#     'itemname': 'HANARO 코스닥150선물레버리지',
#     'nowVal': 10730,
#     'risefall': '2',
#     'changeVal': 290,
#     'changeRate': 2.78,
#     'nav': 10737.0,
#     'threeMonthEarnRate': -5.6289,
#     'quant': 2383,
#     'amonut': 25,
#     'marketSum': 28},
#    {'itemcode': '291630',
#     'etfTabCode': 3,
#     'itemname': 'KOSEF 코스닥150선물레버리지',
#     'nowVal': 5320,
#     'risefall': '2',
#     'changeVal': 155,
#     'changeRate': 3.0,
#     'nav': 5332.0,
#     'threeMonthEarnRate': -5.5901,
#     'quant': 52279,
#     'amonut': 276,
#     'marketSum': 27},
#    {'itemcode': '322150',
#     'etfTabCode': 2,
#     'itemname': 'ACE 스마트하이베타',
#     'nowVal': 13465,
#     'risefall': '2',
#     'changeVal': 140,
#     'changeRate': 1.05,
#     'nav': 13428.0,
#     'threeMonthEarnRate': 3.4496,
#     'quant': 120,
#     'amonut': 1,
#     'marketSum': 27},
#    {'itemcode': '395760',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG ESG성장주액티브',
#     'nowVal': 8815,
#     'risefall': '2',
#     'changeVal': 80,
#     'changeRate': 0.92,
#     'nav': 8812.0,
#     'threeMonthEarnRate': 5.8604,
#     'quant': 105,
#     'amonut': 0,
#     'marketSum': 26},
#    {'itemcode': '145670',
#     'etfTabCode': 3,
#     'itemname': 'ACE 인버스',
#     'nowVal': 5230,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -1.04,
#     'nav': 5227.0,
#     'threeMonthEarnRate': -1.9682,
#     'quant': 15643,
#     'amonut': 81,
#     'marketSum': 26},
#    {'itemcode': '407310',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 200 TOP10',
#     'nowVal': 8470,
#     'risefall': '2',
#     'changeVal': 135,
#     'changeRate': 1.62,
#     'nav': 8501.0,
#     'threeMonthEarnRate': -0.9241,
#     'quant': 97,
#     'amonut': 0,
#     'marketSum': 25},
#    {'itemcode': '433860',
#     'etfTabCode': 7,
#     'itemname': 'ARIRANG TDF2040액티브',
#     'nowVal': 11690,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.21,
#     'nav': 11796.0,
#     'threeMonthEarnRate': 2.1406,
#     'quant': 247,
#     'amonut': 2,
#     'marketSum': 25},
#    {'itemcode': '252720',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 모멘텀밸류',
#     'nowVal': 16260,
#     'risefall': '2',
#     'changeVal': 230,
#     'changeRate': 1.43,
#     'nav': 16245.0,
#     'threeMonthEarnRate': 1.1508,
#     'quant': 1545,
#     'amonut': 25,
#     'marketSum': 24},
#    {'itemcode': '415920',
#     'etfTabCode': 5,
#     'itemname': 'ARIRANG 글로벌희토류전략자원기업MV',
#     'nowVal': 4775,
#     'risefall': '5',
#     'changeVal': -120,
#     'changeRate': -2.45,
#     'nav': 4734.0,
#     'threeMonthEarnRate': -13.3394,
#     'quant': 13859,
#     'amonut': 66,
#     'marketSum': 24},
#    {'itemcode': '275750',
#     'etfTabCode': 3,
#     'itemname': 'KBSTAR 코스닥150선물인버스',
#     'nowVal': 3645,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -1.49,
#     'nav': 3646.0,
#     'threeMonthEarnRate': 1.25,
#     'quant': 9147,
#     'amonut': 33,
#     'marketSum': 24},
#    {'itemcode': '291680',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 차이나H선물인버스(H)',
#     'nowVal': 11810,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.21,
#     'nav': 11906.0,
#     'threeMonthEarnRate': -16.419,
#     'quant': 896,
#     'amonut': 10,
#     'marketSum': 24},
#    {'itemcode': '433850',
#     'etfTabCode': 7,
#     'itemname': 'ARIRANG TDF2030액티브',
#     'nowVal': 11515,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.04,
#     'nav': 11495.0,
#     'threeMonthEarnRate': 2.4922,
#     'quant': 136,
#     'amonut': 1,
#     'marketSum': 23},
#    {'itemcode': '433870',
#     'etfTabCode': 7,
#     'itemname': 'ARIRANG TDF2050액티브',
#     'nowVal': 12580,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 12545.0,
#     'threeMonthEarnRate': 4.5719,
#     'quant': 199,
#     'amonut': 2,
#     'marketSum': 23},
#    {'itemcode': '267450',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 미국장기국채선물인버스(H)',
#     'nowVal': 10730,
#     'risefall': '5',
#     'changeVal': -80,
#     'changeRate': -0.74,
#     'nav': 10758.0,
#     'threeMonthEarnRate': 2.6303,
#     'quant': 103,
#     'amonut': 1,
#     'marketSum': 21},
#    {'itemcode': '412560',
#     'etfTabCode': 2,
#     'itemname': 'TIGER BBIG레버리지',
#     'nowVal': 2105,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 3.69,
#     'nav': 2112.0,
#     'threeMonthEarnRate': -0.4729,
#     'quant': 2163,
#     'amonut': 4,
#     'marketSum': 18},
#    {'itemcode': '402520',
#     'etfTabCode': 1,
#     'itemname': 'FOCUS 혁신기업액티브',
#     'nowVal': 8865,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 0.68,
#     'nav': 8889.0,
#     'threeMonthEarnRate': 8.1361,
#     'quant': 4,
#     'amonut': 0,
#     'marketSum': 18},
#    {'itemcode': '292750',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG KRX300',
#     'nowVal': 17505,
#     'risefall': '2',
#     'changeVal': 145,
#     'changeRate': 0.84,
#     'nav': 17517.0,
#     'threeMonthEarnRate': 2.7891,
#     'quant': 21,
#     'amonut': 0,
#     'marketSum': 18},
#    {'itemcode': '252730',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 모멘텀로우볼',
#     'nowVal': 16205,
#     'risefall': '2',
#     'changeVal': 240,
#     'changeRate': 1.5,
#     'nav': 16152.0,
#     'threeMonthEarnRate': 2.7584,
#     'quant': 10,
#     'amonut': 0,
#     'marketSum': 16},
#    {'itemcode': '391590',
#     'etfTabCode': 4,
#     'itemname': 'ACE 미국스팩&IPO INDXX',
#     'nowVal': 5045,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.88,
#     'nav': 5008.0,
#     'threeMonthEarnRate': -5.701,
#     'quant': 120,
#     'amonut': 0,
#     'marketSum': 15},
#    {'itemcode': '287310',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200경기소비재',
#     'nowVal': 10760,
#     'risefall': '2',
#     'changeVal': 150,
#     'changeRate': 1.41,
#     'nav': 10748.0,
#     'threeMonthEarnRate': -1.1212,
#     'quant': 9451,
#     'amonut': 101,
#     'marketSum': 15},
#    {'itemcode': '287330',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200생활소비재',
#     'nowVal': 6580,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.84,
#     'nav': 6570.0,
#     'threeMonthEarnRate': 10.9051,
#     'quant': 101,
#     'amonut': 0,
#     'marketSum': 14},
#    {'itemcode': '315480',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200커뮤니케이션서비스',
#     'nowVal': 10595,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.47,
#     'nav': 10564.0,
#     'threeMonthEarnRate': -2.188,
#     'quant': 8,
#     'amonut': 0,
#     'marketSum': 13},
#    {'itemcode': '295820',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 200동일가중',
#     'nowVal': 10430,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 10427.0,
#     'threeMonthEarnRate': 3.988,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 10},
#    {'itemcode': '287320',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200산업재',
#     'nowVal': 12395,
#     'risefall': '2',
#     'changeVal': 90,
#     'changeRate': 0.73,
#     'nav': 12359.0,
#     'threeMonthEarnRate': 1.8739,
#     'quant': 8782,
#     'amonut': 108,
#     'marketSum': 10}]}}

# %% [markdown]
# ### JSON 타입으로 데이터 받기

# %%
# requests 의 응답을 json 타입으로 받습니다.
etf_json = response.json()
# etf_json["result"]

# %% [markdown]
# ### JSON 에서 원하는 데이터 찾기

# %%
# result > etfItemList 의 하위 구조로 목록을 찾고자 하는 데이터를 가져옵니다.
etfItemList = etf_json["result"]['etfItemList']
len(etfItemList)
# Out:
# 868

# %% [markdown]
# ## 데이터프레임 변환
# ### JSON 데이터를 pandas 의 데이터프레임 형태로 만들기

# %%
# 키-값 형태의 데이터를 데이터프레임으로 만듭니다.
df = pd.DataFrame(etfItemList)
df.shape
# Out:
# (868, 12)

# %% [markdown]
# ### 데이터 확인

# %%
# 데이터 프레임으로 잘 만들어 졌는지 상단 데이터의 일부만 미리보기 합니다.
df.head()
# Out:
#   itemcode  etfTabCode             itemname   nowVal risefall  changeVal  \
# 0   459580           6    KODEX CD금리액티브(합성)  1038075        2        215
# 1   357870           6  TIGER CD금리투자KIS(합성)    54425        2         20
# 2   069500           1            KODEX 200    36755        2        365
# 3   423160           6  KODEX KOFR금리액티브(합성)   106990        2         20
# 4   449170           6  TIGER KOFR금리액티브(합성)   105540        2         35
#
#    changeRate        nav  threeMonthEarnRate    quant  amonut  marketSum
# 0        0.02  1038075.0              0.9079   331808  344440      90560
# 1        0.04    54421.0              0.9272   161096    8767      72972
# 2        1.00    36797.0              3.1661  2884876  105860      62833
# 3        0.02   106977.0              0.9006    23294    2492      52161
# 4        0.03   105519.0              0.9179    55531    5860      36978

# %%
# 데이터 프레임으로 잘 만들어 졌는지 하단 데이터의 일부만 미리보기 합니다.
df.tail()
# Out:
#     itemcode  etfTabCode             itemname  nowVal risefall  changeVal  \
# 863   287310           2      KBSTAR 200경기소비재   10760        2        150
# 864   287330           2      KBSTAR 200생활소비재    6580        2         55
# 865   315480           2  KBSTAR 200커뮤니케이션서비스   10595        2         50
# 866   295820           1      ARIRANG 200동일가중   10430        3          0
# 867   287320           2        KBSTAR 200산업재   12395        2         90
#
#      changeRate      nav  threeMonthEarnRate  quant  amonut  marketSum
# 863        1.41  10748.0             -1.1212   9451     101         15
# 864        0.84   6570.0             10.9051    101       0         14
# 865        0.47  10564.0             -2.1880      8       0         13
# 866        0.00  10427.0              3.9880      0       0         10
# 867        0.73  12359.0              1.8739   8782     108         10

# %% [markdown]
# ## 파일 저장
# ### 파일명 만들기

# %%
# 파이썬 표준라이브러리인 datetime을 불러옵니다.
# 날짜를 만들어 저장하기 위해 오늘 날짜를 구합니다.
import datetime

today = datetime.datetime.today()
today = today.strftime("%Y-%m-%d")
today
# Out:
# '2024-06-06'

# %%
# f-string 방식으로 파일명을 만들어 줍니다.
# eft_날짜_raw.csv 형태로 만듭니다.
file_name = f"eft_{today}_raw.csv"
file_name
# Out:
# 'eft_2024-06-06_raw.csv'

# %% [markdown]
# ### 파일로 저장하고 불러오기

# %%
# csv 형태로 저장합니다. index 가 저장되지 않도록 합니다.
df.to_csv(file_name, index=False)

# %%
import pandas as pd
# 저장된 csv 파일을 읽어옵니다.
# itemcode 숫자 앞의 0 이 지워진다면 dtype={"itemcode": object} 로 타입을 지정해 주면 문자형태로 읽어옵니다.
pd.read_csv(file_name, dtype={"itemcode": object})
# Out:
#     itemcode  etfTabCode             itemname   nowVal  risefall  changeVal  \
# 0     459580           6    KODEX CD금리액티브(합성)  1038075         2        215
# 1     357870           6  TIGER CD금리투자KIS(합성)    54425         2         20
# 2     069500           1            KODEX 200    36755         2        365
# 3     423160           6  KODEX KOFR금리액티브(합성)   106990         2         20
# 4     449170           6  TIGER KOFR금리액티브(합성)   105540         2         35
# ..       ...         ...                  ...      ...       ...        ...
# 863   287310           2      KBSTAR 200경기소비재    10760         2        150
# 864   287330           2      KBSTAR 200생활소비재     6580         2         55
# 865   315480           2  KBSTAR 200커뮤니케이션서비스    10595         2         50
# 866   295820           1      ARIRANG 200동일가중    10430         3          0
# 867   287320           2        KBSTAR 200산업재    12395         2         90
#
#      changeRate        nav  threeMonthEarnRate    quant  amonut  marketSum
# 0          0.02  1038075.0              0.9079   331808  344440      90560
# 1          0.04    54421.0              0.9272   161096    8767      72972
# 2          1.00    36797.0              3.1661  2884876  105860      62833
# 3          0.02   106977.0              0.9006    23294    2492      52161
# 4          0.03   105519.0              0.9179    55531    5860      36978
# ..          ...        ...                 ...      ...     ...        ...
# 863        1.41    10748.0             -1.1212     9451     101         15
# 864        0.84     6570.0             10.9051      101       0         14
# 865        0.47    10564.0             -2.1880        8       0         13
# 866        0.00    10427.0              3.9880        0       0         10
# 867        0.73    12359.0              1.8739     8782     108         10
#
# [868 rows x 12 columns]
